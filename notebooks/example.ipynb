# %% [markdown]
# # Example Notebook
#
# This is an example Jupyter notebook to demonstrate the notebook viewer.

# %%
import json
print('Hello from Studio-NoteBookIPYNB!')

# %% [markdown]
# ## Features
#
# - View notebooks in the browser
# - Support for code and markdown cells
# - Fast loading and rendering
